# %% [markdown]
# TITLE:            Calculating the averages of climate variables under SSP245, SAI 1p0, SAI 1p5.
# PROJECT:          "Climate analogs under SAI"
# AUTHORS:          Ruoyu Chen
# COLLABORATORS:
# DATA INPUT:       5 (06 to 10) ensemble files from Precipitation and Temperature for each of SSP245, SAI 1p0, SAI 1p5 scenarios.
#
# DATA OUTPUT:      Dataframe/netcdf file of the average over a selected period for Precip and Temp for the 3 climate scenarios. Saved in the ensemble_avg folders (for HPCC only...)
# DATE:             initiated: 5 June 2026; last run: ____
# OVERVIEW:         Root path is: . Everything else is based on that root
# REQUIRES:         30 files, 5 for each category. DID NOT ACTUALLY CHANGE CODE TO REFLECT YET. NOT ALL 06-10 ENSEMBLES ARE AVAILABLE.
# NOTES:            None

# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import seaborn as sns
import geopandas as gpd
import earthpy as et
import xarray as xr
# Spatial subsetting of netcdf files
import regionmask


# Plotting options
sns.set(font_scale=1.3)
sns.set_style("white")


import warnings
warnings.filterwarnings(
    "ignore",
    message="pkg_resources is deprecated as an API.*",
    category=UserWarning
)

import earthpy as et

# %%
#Function pulling everything together for precipitation data: 
def create_avg_ncfile_prect(climate_scenario, climate_variable, start_year, end_year):
    path_files = []
    time_sliced_files = []
    # Get the list of all files and directories
    path = "/mnt/research/nasabio/data/climate/L1/" + climate_scenario + "/" + climate_variable 
    list_of_files = os.listdir(path)
    for each in list_of_files[:]: 
        if (each == "p95_threshold.nc"): #Removes an irrelevant file in the folder. Is not ensemble member. 
            list_of_files.remove(each)
        else: 
            file = xr.open_dataset(path + "/" + each)
            path_files.append(file)
    
    #For every ensemble, collapse the "year" dimension by averaging all values across the years at every lat and lon. 
    for each in range(len(path_files)): 
        sliced = path_files[each].sel(year = slice(start_year, end_year))
        each_ensemble_avg = sliced.mean(dim='year')
        time_sliced_files.append(each_ensemble_avg)

    # As a check of the code, let's look at if the first ensemble came out correctly. 
    # sliced1 = path_files[0].sel(year = slice(start_year, end_year)) #Data over the specified years. 
    # print(sliced1['CDD'].values[:, 2, 0]) #Here is the first value of the 3rd row for each of the 20 years. 
    # print((sliced1['CDD'].values[:, 2, 0]).mean()) #And it's mean. 
    # print(time_sliced_files[0]['CDD'].values[2, 0]) #And compare that with the 3rd row, 1st column of the averaged data. 
    
    concat_files_avg=xr.concat(time_sliced_files, dim='time').mean(dim='time')
    
    save_path = "/mnt/research/nasabio/data/climate/L1/" + climate_scenario + "/ensemble_avg/"
    file_name = "EXAMPLE_" + climate_scenario + "_avg_" + climate_variable + "_values_" + str(start_year) + "-" + str(end_year)+ ".nc"
    concat_files_avg.to_netcdf(save_path + file_name)
    return concat_files_avg

# %%
#Function pulling everything together for temperature data: 
def create_avg_ncfile_tsmx(climate_scenario, climate_variable, start_year, end_year):
    path_files = []
    time_sliced_files = []
    path = "/mnt/research/nasabio/data/climate/L1/" + climate_scenario + "/" + climate_variable + "/extreme_high" 
    list_of_files = os.listdir(path)
    for each in list_of_files[:]: 
        file = xr.open_dataset(path + "/" + each)
        path_files.append(file)
    
    for each in range(len(path_files)):
        ssliced = path_files[each].sel(year = slice(start_year, end_year))
        each_ensemble_avg = sliced.mean(dim='year')
        time_sliced_files.append(each_ensemble_avg)
    
    concat_files_avg=xr.concat(time_sliced_files, dim='time').mean(dim='time')
    
    save_path = "/mnt/research/nasabio/data/climate/L1/" + climate_scenario + "/ensemble_avg/"
    file_name = "EXAMPLE_" + climate_scenario + "_avg_" + climate_variable + "_values_" + str(start_year) + "-" + str(end_year)+ ".nc"
    concat_files_avg.to_netcdf(save_path + file_name)
    return concat_files_avg

# %%
create_avg_ncfile_tsmx("SSP245", "TSMX", 2015, 2034) #This finds the average of the present period in SSP245 for temp. 
create_avg_ncfile_prect("SSP245", "PRECT", 2015, 2034) #This finds the average of the present period in SSP245 for precip. 

create_avg_ncfile_tsmx("SSP245", "TSMX", 2035, 2069) #This finds the average of the future period in SSP245 for temp. 
create_avg_ncfile_prect("SSP245", "PRECT", 2035, 2069) #This finds the average of the future period in SSP245 for precip.
# Out:
# <xarray.Dataset> Size: 889kB
# Dimensions:  (lat: 192, lon: 288)
# Coordinates:
#   * lat      (lat) float64 2kB -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon      (lon) float64 2kB 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
# Data variables:
#     CDD      (lat, lon) float32 221kB 93.14 93.14 93.14 ... 37.37 37.37 37.37
#     CWD      (lat, lon) float32 221kB 3.014 3.014 3.014 ... 5.543 5.543 5.543
#     PRCPTOT  (lat, lon) float32 221kB 85.42 85.42 85.42 ... 249.6 249.6 249.6
#     R95pTOT  (lat, lon) float32 221kB 5.905 5.905 5.905 ... 29.13 29.13 29.13
# Attributes:
#     scenario:                  SSP245
#     member:                    007
#     variable:                  PRECT
#     clim_reference:            SSP245 2015-2034
#     wet_day_threshold_mm_day:  1.0
#     source_unit_conversion:    PRECT [m/s] x 86400 x 1000 -> mm/day

# %%
create_avg_ncfile_prect("ARISE_SAI_1p5", "PRECT", 2050, 2069)
create_avg_ncfile_tsmx("ARISE_SAI_1p5", "TSMX", 2050, 2069) #missing 4


create_avg_ncfile_prect("ARISE_SAI_1p0", "PRECT", 2050, 2069) #Missing 8. 
create_avg_ncfile_tsmx("ARISE_SAI_1p0", "TSMX", 2050, 2069) #Missing 2 and 4.
# Out:
# <xarray.Dataset> Size: 889kB
# Dimensions:  (lat: 192, lon: 288)
# Coordinates:
#   * lat      (lat) float64 2kB -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon      (lon) float64 2kB 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
# Data variables:
#     CDD      (lat, lon) float32 221kB 104.8 104.8 104.8 104.8 ... 40.6 40.6 40.6
#     CWD      (lat, lon) float32 221kB 2.8 2.8 2.8 2.8 2.8 ... 4.8 4.8 4.8 4.8
#     PRCPTOT  (lat, lon) float32 221kB 76.24 76.24 76.24 ... 228.7 228.7 228.7
#     R95pTOT  (lat, lon) float32 221kB 5.581 5.581 5.581 ... 25.89 25.89 25.89
# Attributes:
#     scenario:                  SSP245
#     member:                    009
#     variable:                  PRECT
#     clim_reference:            SSP245 2015-2034
#     wet_day_threshold_mm_day:  1.0
#     source_unit_conversion:    PRECT [m/s] x 86400 x 1000 -> mm/day
